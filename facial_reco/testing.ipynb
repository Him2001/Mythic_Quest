# %%
import os, onnx
for name in ["scrfd_10g_bnkps.onnx", "w600k_r50.onnx"]:
    path = os.path.join("models", name)
    print("\nChecking", path)
    print("  Exists:", os.path.exists(path), "Size:", os.path.getsize(path)//1024//1024, "MB")
    onnx.load(path)
    print("  ✅ ONNX file is valid")
# Out:
# Checking models\scrfd_10g_bnkps.onnx
#   Exists: True Size: 16 MB
#   ✅ ONNX file is valid
#
# Checking models\w600k_r50.onnx
#   Exists: True Size: 166 MB
#   ✅ ONNX file is valid
